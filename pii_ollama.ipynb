# %% [markdown]
# # 🦙 Ollama direct redaction
#
# This notebooks explores using LLM models directly to identify `Personal Identifyable Information` (PII).
#
# > ℹ️ We use [Ollama](https://ollama.com/download/linux) and markdown inputs as produced by something like [docLing](https://docs.vllm.ai/en/stable/)

# %% [markdown]
# ## ⚙️ Setup

# %%
# install uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh

# Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# !uv pip install -q --system ollama tqdm rich funcy
# Out:
# downloading uv 0.6.11 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /root/.local/bin
#   uv
#   uvx
# everything's installed!
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# #######################################                                   54.3%

# %% [markdown]
# ## 🦜 LLM
#
# Let's check some random LLM chatter 🗣️
#
# > You will need to run in a separate terminal:
# > ```shell
# > ollama serve &
# > ollama pull phi4
# > ```

# %%
from ollama import chat
from ollama import ChatResponse

# ===================================== 👇 Configure as needed =================================
MODEL_ID = "llama3.3:latest", # "phi4", "deepseek-r1", "qwen2.5:14b"
DEFAULT_SYS_PROMPT = "You are a helpful AI assistant."
# ===================================== 👆 Configure as needed =================================


def stream_response(stream):
    for chunk in stream:
        print(chunk, end='', flush=True)
        

def generate_stream(prompt: str, sys_prompt:str = DEFAULT_SYS_PROMPT, **options):
    messages = [
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": prompt},
    ]
    stream = chat(
        model=MODEL_ID, messages=messages, stream=True, **options
    )
    for chunk in stream:
        yield chunk['message']['content']

        
def generate(prompt: str, sys_prompt:str = DEFAULT_SYS_PROMPT, **options):
    messages = [
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": prompt},
    ]
    response = chat(model=MODEL_ID, messages=messages, **options)
    return response.message.content


# Run inference
ans = generate("Hey there. Say hello in german.")
print(f"🗣️ Answer:")
print(ans)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 37
#      33     return response.message.content
#      36 # Run inference
# ---> 37 ans = generate("Hey there. Say hello in german.")
#      38 print(f"🗣️ Answer:")
#      39 print(ans)
#
# Cell In[4], line 32, in generate(prompt, sys_prompt, **options)
#      27 def generate(prompt: str, sys_prompt:str = DEFAULT_SYS_PROMPT, **options):
#      28     messages = [
#      29         {"role": "system", "content": sys_prompt},
#      30         {"role": "user", "content": prompt},
#      31     ]
# ---> 32     response = chat(model=MODEL_ID, messages=messages, **options)
#      33     return response.message.content
#
# File /usr/local/lib/python3.11/dist-packages/ollama/_client.py:337, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)
#     298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)
#     331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
#     333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
# --> 337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File /usr/local/lib/python3.11/dist-packages/pydantic/main.py:243, in BaseModel.__init__(self, **data)
#     241 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     242 __tracebackhide__ = True
# --> 243 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     244 if self is not validated_self:
#     245     warnings.warn(
#     246         'A custom validator is returning a value other than `self`.\n'
#     247         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     248         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     249         stacklevel=2,
#     250     )
#
# ValidationError: 1 validation error for ChatRequest
# model
#   Input should be a valid string [type=string_type, input_value=('llama3.3:latest',), input_type=tuple]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type

# %% [markdown]
# ## 📚 Data

# %%
import re
from pathlib import Path
from utils import split_markdown_by_spans

DATA_DIR = Path("/datasets/client-data-us/")

md_docs = list(DATA_DIR.rglob("**/*.md"))
print(f"Total markdown documents: {len(md_docs)}")
# Out:
# Total markdown documents: 60

# %% [markdown]
# ## 🫥 Anonymisation

# %% [markdown]
# ### 🗣️ Prompts

# %%
# System prompt
SYSTEM_PROMPT = """
You are specialized in extracting Personal Identifiable Information (PII).
Identifying information are things like, but not limited to:

- Organizations: Organization and Company names (should not include placehoders. e.g.: Developer, Customer, Client,...)
- Persons: Names of persons or individuals (should not include Organizations, Companies nor Place names)
- Locations: (city names, countries) and addresses
- Contact information: Emails, phone numbers and PO boxes
- Dates: Should not inlcude time periods or durations, nor single numbers. Only full dates at least containing year and month

Answer only with the PII, if none is found, say 'None'

<example>

Given the following text:

```
This contract is between Customer and Supply Chain Consultants, Inc. 
Arkieva Linden Green Center 5460 Fairmont Drive Wilmington, DE 19808 
Telephone: 302-738-9215 Fed ID/TIN
```

- **company names**: Supply Chain Consultants, Inc
- **locations**: Arkieva Linden Green Center 5460 Fairmont Drive Wilmington, DE 19808
- **phone numbers**: 302-738-9215

</example>
"""

# Summary template
SUMMARY_TEMPLATE = """
Given the following legal text, please provide a summary of the main points.

```
{context}
```
"""

# %% [markdown]
# ### 🚀 Go

# %%
import json

from collections import defaultdict
from dateutil import parser
from funcy import chunks
from pprint import pformat
from pydantic import BaseModel, Field, field_validator
from tqdm.auto import tqdm


class PIIEntities(BaseModel):
    dates: list[str] = Field(default_factory=list, description="List of identified calendar dates.")
    person_names: list[str] = Field(default_factory=list, description="List of Person's or individual names")
    orgs: list[str] = Field(default_factory=list, description="List of identified company names.")
    telephones: list[str] = Field(default_factory=list, description="List of identified telephone numbers")
    emails: list[str] = Field(default_factory=list, description="List of identified email addresses")
    locations: list[str] = Field(default_factory=list, description="List of identified locations and addresses")
    
                                    
    @field_validator("dates")
    @classmethod
    def validate_dates(cls, dates):
        valid_dates = []
        for date_str in dates:
            # If it parses as float is not a date
            try:
                float(date_str)
                continue
            except ValueError:
                pass
            
            # Attempt to parse the date string with fuzzy parsing disabled
            try:
                parsed_date = parser.parse(date_str, fuzzy=False)
                valid_dates.append(date_str)
            except ValueError:
                # If parsing fails, skip this date string
                print(f"Invalid date format: '{date_str}'")
                
        return valid_dates
                                
                                    

def inspect_for_piis(text, chunk_size:int = 400):
    # Look for stuff in chunks (simple for now, but to avoid catastrophical forgetting)
    total_chunks = len(text) // chunk_size + int(len(text) % chunk_size > 0)
    
    piis = defaultdict(list)
    chunks_pbar = tqdm(chunks(chunk_size, text), total=total_chunks)
    for i, chunk in enumerate(chunks_pbar):
        chunks_pbar.set_description(f"Chunk {i}")
        res = generate(
            chunk,
            sys_prompt=SYSTEM_PROMPT,
            format=PIIEntities.model_json_schema()
        )
        # print(f"\n\n===================== Chunk {i} =====================")
        for cat, vals in json.loads(res).items():
            piis[cat] += vals
            
    return piis


# Read the 1st document
text = md_docs[0].open("r").read()

# Inspect for PIIs
piis = inspect_for_piis(text)
print(json.dumps(piis, indent=2))
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# {
#   "orgs": [
#     "Supply Chain Consultants, Inc.",
#     "Ardieva Linden Green Center",
#     "BUCKMAN LABORATORIES INTERNATIONAL, INC.",
#     "Developer",
#     "Supply Chain Consultants, Inc.",
#     "Arkieva",
#     "Customer",
#     "Developer",
#     "Developer",
#     "Developer",
#     "Developer",
#     "Customer",
#     "Developer",
#     "U.S. Commerce Department",
#     "Supply Chain Consultants, Inc.",
#     "Buckman Laboratories International Inc."
#   ],
#   "locations": [
#     "5460 Fairmont Drive Wilmington, DE 19808",
#     "1256 North McLean Boulevard, Memphis Tennessee 38108-1241, U.S.A.",
#     "N OF DISTRIBUTOR6",
#     "TERMINATION7",
#     "QUALITY CONTROL7",
#     "ASSIGNMENT7",
#     "U.S. EXPORT RESTRICTIONS7",
#     "MISCELLANEOUS8",
#     "Buckman Laboratories International Inc.",
#     "Designated Hardware",
#     "",
#     "page 9 of this Agreement",
#     "#page-3-0",
#     "page-3-1",
#     "None",
#     "None",
#     "None identified beyond section numbers.",
#     "None",
#     "none",
#     "none",
#     "none",
#     "none",
#     "none",
#     "none",
#     "none",
#     "none",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "None",
#     "Wilmington",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "N/A",
#     "None",
#     "#page-6-0",
#     "None",
#     "Sections 8.0",
#     "9.0",
#     "10.0",
#     "11.0",
#     "None",
#     "U.S.",
#     "U.S.",
#     "U.S.",
#     "State of Delaware",
#     "Arkieva",
#     "August 17, 2012",
#     "Arkieva",
#     "Zemeter Products Licensed",
#     "Zemeter",
#     "Customer locations",
#     "Arkieva",
#     "COO, Arkieva",
#     "August 17, 2012"
#   ],
#   "person_names": [
#     "Omer",
#     "Customer",
#     "Developer",
#     "Distributor",
#     "Developer",
#     "Customer",
#     "Customer",
#     "Developer",
#     "Customer",
#     "Developer",
#     "Developer",
#     "Customer",
#     "Developer",
#     "Developer",
#     "Customer",
#     "Customer",
#     "Develope",
#     "Customer",
#     "Developer",
#     "Developer",
#     "Customer",
#     "Sujit K. Singh",
#     "Sujit K. Singh"
#   ],
#   "dates": [
#     "60 days"
#   ]
# }

# %%
import re

re.search("Continental Foods Europe BVBA", text)
# Out:
# <re.Match object; span=(24746, 24775), match='Continental Foods Europe BVBA'>

# %%
# map each entity to a placeholder and substitute in the original text
placeholders = {}
for doc_name, doc_entities in entities.items():
    placeholders[doc_name] = {}
    for ent_type, ent_list in doc_entities.items():
        for i, ent in enumerate(ent_list):
            placeholders[doc_name][ent] = f"{ent_type.upper()}_{i}" 

print(pformat(placeholders))
# Out:
# {'Buckman Master License Agreement': {'Arkieva': 'ORGS_5',
#                                       'Buckman Laboratories International Inc.': 'ORGS_6',
#                                       'Buckman Laboratories International Inc. (Customer)': 'PEOPLE_0',
#                                       'Customer': 'PEOPLE_15',
#                                       "Customer's consultants": 'PEOPLE_11',
#                                       "Customer's employees": 'PEOPLE_10',
#                                       "Customer's employees, consultants, or affiliates": 'PEOPLE_12',
#                                       'Developer': 'PEOPLE_13',
#                                       'Distributor': 'PEOPLE_14',
#                                       'Distributors': 'ORGS_4',
#                                       'Licensor': 'PEOPLE_6',
#                                       'Licensors': 'ORGS_2',
#                                       'Parties': 'PEOPLE_16',
#                                       'Parties (mentioned twice, but referring to the same entities as Developer and Distributor)': 'PEOPLE_17',
#                                       'Representatives': 'ORGS_3',
#                                       'Sujit K. Singh': 'PEOPLE_18',
#                                       'Supply Chain Consultants, Inc. d/b/a Arkieva': 'ORGS_1',
#                                       'Supply Chain Consultants, Inc. d/b/a Arkieva (Developer)': 'PEOPLE_1'},
#  'Customer10_MLSA_1272021': {'Arkieva': 'PEOPLE_2',
#                              'Arkieva (mentioned in the context of the Arkieva Service Level Agreement)': 'PEOPLE_6',
#                              'Blair, Nebraska': 'LOC_2',
#                              'Customer': 'PEOPLE_10',
#                              "Customer's": 'PEOPLE_18',
#                              "Customer's affiliates": 'PEOPLE_13',
#                              "Customer's consultants": 'PEOPLE_14',
#                              "Customer's designees": 'PEOPLE_16',
#                              "Customer's employees": 'PEOPLE_12',
#                              'Developer': 'PEOPLE_11',
#                              "Developer's": 'PEOPLE_17',
#                              "Developer's agents": 'PEOPLE_20',
#                              "Developer's employees": 'PEOPLE_19',
#                              "Developer's subcontractors": 'PEOPLE_21',
#                              'NatureWorks LLC': 'ORGS_6',
#                              'Reseller': 'PEOPLE_3',
#                              'Sub-provider or sub-contractor': 'PEOPLE_15',
#                              'Such other address as Developer or Customer shall provide to receive notices under this Agreement (not specified in the text)': 'LOC_1',
#                              'Sujit Singh': 'ORGS_0',
#                              'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_3',
#                              'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_7',
#                              'The address provided above (not specified in the text)': 'LOC_0',
#                              "Third party's (in the context of warranties and intellectual property rights)": 'PEOPLE_9',
#                              'William A. Suehr III': 'ORGS_1',
#                              'William Suehr': 'PEOPLE_28'},
#  'Customer11_MLSA_07292022': {'Arkieva': 'ORGS_4',
#                               'Customer': 'PEOPLE_10',
#                               'Customer Initials': 'PEOPLE_5',
#                               'Developer': 'PEOPLE_11',
#                               'Developer Initials': 'PEOPLE_6',
#                               'Mark Schmidt': 'ORGS_6',
#                               'Mark Schmidt (CIO, Customer)': 'PEOPLE_14',
#                               'Parties (implied to be the Developer and Customer)': 'PEOPLE_9',
#                               'Reseller': 'PEOPLE_3',
#                               'Sujit K Singh': 'ORGS_5',
#                               'Sujit K Singh (COO)': 'ORGS_7',
#                               'Sujit K Singh (COO, Developer)': 'PEOPLE_15',
#                               'Westlake Chemical': 'ORGS_3'},
#  'Customer15_MLSA_04192021': {'Accountants': 'PEOPLE_9',
#                               'Alex Browning': 'ORGS_0',
#                               'Arkieva': 'PEOPLE_2',
#                               'Consultants': 'PEOPLE_8',
#                               'Customer': 'PEOPLE_5',
#                               'Customer Incorporated (Customer)': 'ORGS_7',
#                               "Customer's": 'PEOPLE_13',
#                               "Customer's (implied, as the policy belongs to the Customer)": 'PEOPLE_18',
#                               'Developer': 'PEOPLE_6',
#                               "Developer's": 'PEOPLE_17',
#                               "Developer's agents": 'PEOPLE_15',
#                               "Developer's employees": 'PEOPLE_14',
#                               "Developer's subcontractors": 'PEOPLE_16',
#                               'Employees': 'PEOPLE_7',
#                               'Governmental regulatory authorities': 'PEOPLE_10',
#                               'Reseller': 'PEOPLE_3',
#                               'Ritesh Tanna': 'ORGS_2',
#                               'Sujit Singh': 'ORGS_1',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_8',
#                               'Third parties (implied, not specific individuals)': 'PEOPLE_11'},
#  'Customer20_MLSA_12092021': {'Arkieva': 'PEOPLE_2',
#                               'Customer': 'PEOPLE_7',
#                               'Developer': 'PEOPLE_4',
#                               'Lallemand Inc.': 'ORGS_6',
#                               'Mark Worthey': 'PEOPLE_13',
#                               'Mark Worthey (Lallemand Inc.)': 'PEOPLE_15',
#                               'Reseller': 'PEOPLE_3',
#                               'Sujit K Singh': 'PEOPLE_14',
#                               'Sujit K Singh (Supply Chain Consultants Inc. d/b/a Arkieva)': 'PEOPLE_16',
#                               'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_7',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_5',
#                               'Supply Chain Consultants Inc. d/b/a Arkieva': 'ORGS_3',
#                               'Third party (implied, not a person but a legal entity)': 'PEOPLE_6',
#                               'Vendor (implied as Developer)': 'PEOPLE_8'},
#  'Customer22_MLA_03152022': {'Consultant': 'PEOPLE_0',
#                              'Customer': 'PEOPLE_1',
#                              'Licensor': 'ORGS_3',
#                              'Nobian Industrial Chemicals BV': 'ORGS_5',
#                              'Patrick Kohlmann': 'PEOPLE_4',
#                              'Representative (of Consultant)': 'PEOPLE_2',
#                              'Sujit K Singh': 'PEOPLE_3',
#                              'Supply Chain Consultants, Inc. (referred to as Consultant)': 'ORGS_0',
#                              'Supply Chain Consultants, Inc. dba Arkieva, Inc.': 'ORGS_4'},
#  'Customer23_MLSA_12012020': {'Accountants': 'PEOPLE_7',
#                               'Arkieva Inc.': 'ORGS_4',
#                               'Consultants': 'PEOPLE_6',
#                               'Customer': 'ORGS_1',
#                               "Customer's": 'PEOPLE_11',
#                               'Developer': 'ORGS_0',
#                               "Developer's": 'PEOPLE_10',
#                               "Developer's agents": 'PEOPLE_13',
#                               "Developer's employees": 'PEOPLE_12',
#                               "Developer's subcontractors": 'PEOPLE_14',
#                               'Distributor': 'ORGS_2',
#                               'Employees': 'PEOPLE_5',
#                               'Governmental regulatory authorities': 'PEOPLE_8',
#                               'Jeffrey Barlow': 'PEOPLE_21',
#                               'Licensor': 'PEOPLE_2',
#                               'Momentive Performance Materials Quartz, Inc. d/b/a Momentive Technologies': 'ORGS_11',
#                               'Momentive Performance Materials Quartz, Inc. d/b/a Momentive Technologies (Customer)': 'PEOPLE_23',
#                               'Public (in the context of information that is not deemed confidential)': 'PEOPLE_9',
#                               'Sujit K Singh': 'PEOPLE_22',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_12'},
#  'Customer29_MLSA_05272021': {'Accountants': 'PEOPLE_10',
#                               'Affiliates (as part of the agreement)': 'PEOPLE_3',
#                               'Arkieva': 'PEOPLE_2',
#                               'Arkieva (DBA Arkieva)': 'ORGS_3',
#                               'Client Incorporated (Client)': 'ORGS_4',
#                               'Consultants': 'PEOPLE_9',
#                               'Customer': 'PEOPLE_13',
#                               'Customer Incorporated (Customer)': 'ORGS_8',
#                               'Customer Torani R & Company, Inc.': 'ORGS_2',
#                               "Customer's employees": 'PEOPLE_15',
#                               'Developer': 'PEOPLE_14',
#                               "Developer's agents": 'PEOPLE_17',
#                               "Developer's employees": 'PEOPLE_16',
#                               "Developer's subcontractors": 'PEOPLE_18',
#                               'Employees': 'PEOPLE_8',
#                               'Governmental regulatory authorities': 'PEOPLE_11',
#                               'Public (implied as a group)': 'PEOPLE_12',
#                               'Reseller (as an approved third party)': 'PEOPLE_4',
#                               'Scott Triou': 'PEOPLE_23',
#                               'Scott Triou (CFO)': 'PEOPLE_19',
#                               'Scott Triou (Customer Developer)': 'PEOPLE_25',
#                               'Sujit K Singh': 'ORGS_1',
#                               'Sujit K Singh (COO)': 'ORGS_7',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_9',
#                               'Torani R & Company Inc': 'ORGS_0',
#                               'Torani R & Company, Inc.': 'ORGS_6'},
#  'Customer2_MLSA_09062022': {'Arkieva': 'ORGS_8',
#                              'Camille De Bruyn': 'PEOPLE_14',
#                              'Customer': 'PEOPLE_10',
#                              'Customer Incorporated (Customer)': 'PEOPLE_17',
#                              "Customer's": 'PEOPLE_6',
#                              'Developer': 'PEOPLE_11',
#                              "Developer's": 'PEOPLE_5',
#                              "Developer's agents": 'PEOPLE_8',
#                              "Developer's employees": 'PEOPLE_7',
#                              "Developer's subcontractors": 'PEOPLE_9',
#                              'DocuSign': 'ORGS_9',
#                              'Implementers (implied by "implementation fees")': 'ORGS_3',
#                              'Licensors': 'ORGS_1',
#                              'Paul Depuydt': 'PEOPLE_13',
#                              "Ravago BU's": 'ORGS_5',
#                              'Ravago Business Units': 'ORGS_7',
#                              'Representatives': 'ORGS_2',
#                              'Reseller': 'PEOPLE_3',
#                              'Sujit Singh': 'PEOPLE_12',
#                              'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_6',
#                              'Supply Chain Consultants Inc. DBA Arkieva (Developer)': 'PEOPLE_18'},
#  'Customer31_MLSA_03112024': {'Arkieva (mentioned in the context of providing documentation and hosting services)': 'PEOPLE_0',
#                               'Arkieva Supply Chain Technologies Private Limited': 'ORGS_3',
#                               'Customer': 'PEOPLE_10',
#                               'Customer (mentioned as a party to the agreement and as the owner of the data)': 'PEOPLE_1',
#                               "Customer's (implied)": 'PEOPLE_15',
#                               'Developer': 'PEOPLE_9',
#                               'Developer (mentioned as a party to the agreement and as the provider of products and services)': 'PEOPLE_2',
#                               "Developer's": 'PEOPLE_14',
#                               "Developer's agents": 'PEOPLE_12',
#                               "Developer's employees": 'PEOPLE_11',
#                               "Developer's subcontractors": 'PEOPLE_13',
#                               'Pawan Satyawali': 'PEOPLE_18',
#                               'Reseller (mentioned as an approved third party)': 'PEOPLE_3',
#                               'Sujit K. Singh': 'PEOPLE_19',
#                               'Tata Consumer Products Limited': 'ORGS_2',
#                               'Third-Party Components (not a person, but a term referring to third-party products or materials)': 'PEOPLE_6'},
#  'Customer32_MLSA_12012019': {'Client Incorporated (Client)': 'ORGS_3',
#                               'Customer Initials': 'PEOPLE_1',
#                               "Customer's": 'PEOPLE_6',
#                               'David Johnston': 'ORGS_0',
#                               'Developer': 'PEOPLE_3',
#                               'Developer Initials': 'PEOPLE_2',
#                               "Developer's": 'PEOPLE_5',
#                               "Developer's agents": 'PEOPLE_8',
#                               "Developer's employees": 'PEOPLE_7',
#                               "Developer's subcontractors": 'PEOPLE_9',
#                               'Jorge Carlino': 'ORGS_1',
#                               'Licensor': 'PEOPLE_4',
#                               'Messer North America, Inc.': 'ORGS_5',
#                               'Sanjay Nambiar': 'PEOPLE_16',
#                               'Sujit K. Singh': 'ORGS_2',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_4'},
#  'Customer38_MLSA_08072023': {'Ansa Decoglass Private Limited': 'ORGS_9',
#                               'Ansa Decoglass Pvt. Ltd.': 'ORGS_7',
#                               'Customer': 'PEOPLE_7',
#                               'Developer': 'PEOPLE_8',
#                               'Kosamba Plant of PGP Glass Pvt. Ltd.': 'ORGS_6',
#                               'Licensor': 'PEOPLE_3',
#                               'Mr. Samit Datta': 'PEOPLE_15',
#                               'Mr. Samit Datta (COO)': 'ORGS_3',
#                               'PGP Glass Private Limited': 'ORGS_10',
#                               'Parties (implied to be the Developer and Customer)': 'PEOPLE_6',
#                               'Sujit K Singh': 'PEOPLE_16',
#                               'Sujit K Singh (Global Chief Supply Chain & Technology Officer)': 'ORGS_2',
#                               'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_5',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_11'},
#  'Customer3_MLSA_12232023': {"5460 Fairmont Drive, Wilmington DE 19808 USA (Developer's principal place of business)": 'LOC_1',
#                              'Affiliates of Arkieva (implied, as they are mentioned in the context of being able to purchase Products or Services under the Agreement)': 'ORGS_3',
#                              'Affiliates of Customer': 'PEOPLE_5',
#                              'Arkieva': 'PEOPLE_4',
#                              'Customer': 'PEOPLE_20',
#                              "Customer's": 'PEOPLE_27',
#                              "Customer's (implied, as the policy belongs to the Customer)": 'PEOPLE_25',
#                              'Customer, Inc.': 'ORGS_11',
#                              'Developer': 'PEOPLE_19',
#                              "Developer's": 'PEOPLE_26',
#                              "Developer's agents": 'PEOPLE_22',
#                              "Developer's employees": 'PEOPLE_21',
#                              "Developer's representative": 'PEOPLE_10',
#                              "Developer's subcontractors": 'PEOPLE_23',
#                              "Gwattstrasse 15 8808 Pfaeffikon Switzerland (Customer's principal place of business)": 'LOC_0',
#                              'JN JN': 'PEOPLE_13',
#                              'JN James Ni, SVP, Latex Binders': 'PEOPLE_30',
#                              'JNSVP, Latex Binders': 'ORGS_9',
#                              'James Ni': 'PEOPLE_28',
#                              'Licensors': 'PEOPLE_11',
#                              'Parties (implied to be the Developer and Customer)': 'PEOPLE_16',
#                              'Representatives': 'PEOPLE_12',
#                              'Reseller': 'PEOPLE_6',
#                              'Sujit Singh': 'PEOPLE_29',
#                              'Sujit Singh, COO': 'PEOPLE_31',
#                              'Sujit Singh, Developer': 'PEOPLE_32',
#                              'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_12',
#                              'Supply Chain Consultants Inc. d/b/a Arkieva Inc.': 'PEOPLE_1',
#                              'Trinseo': 'ORGS_13',
#                              'Trinseo (as indicated by the URL provided in the text: [www.trinseo.com](http://www.trinseo.com/))': 'ORGS_10',
#                              'Trinseo Europe GMBH': 'PEOPLE_0'},
#  'Customer42_MLA_08072017': {'Accountants': 'PEOPLE_9',
#                              'Arkieva': 'ORGS_0',
#                              'Arkieva Inc.': 'ORGS_4',
#                              'Arkieva Inc. (Customer)': 'LOC_0',
#                              'Arkieva Solution set': 'ORGS_1',
#                              'Consultants': 'PEOPLE_8',
#                              'Customer': 'PEOPLE_6',
#                              "Customer's": 'PEOPLE_1',
#                              'Delaware (Governing law location)': 'LOC_2',
#                              'Designated Hardware': 'ORGS_2',
#                              'Developer': 'PEOPLE_5',
#                              "Developer's": 'PEOPLE_0',
#                              'Employees': 'PEOPLE_7',
#                              'Governmental regulatory authorities': 'PEOPLE_10',
#                              'John Zeiser': 'PEOPLE_13',
#                              'Licensor': 'PEOPLE_4',
#                              'Public (in the context of information that is not confidential)': 'PEOPLE_11',
#                              'Southern Champion Tray (Client)': 'LOC_1',
#                              'Sujit K Singh': 'PEOPLE_12',
#                              'U.S. Commerce Department': 'ORGS_3'},
#  'Customer48_MLSA_05032021': {'Accountants': 'PEOPLE_11',
#                               'Alex Mendes': 'ORGS_0',
#                               'Arkieva': 'PEOPLE_2',
#                               'Arlon Graphics Materials CO, LTD': 'ORGS_4',
#                               'Consultants': 'PEOPLE_10',
#                               'Customer': 'PEOPLE_14',
#                               'Customer Incorporated (Customer)': 'ORGS_5',
#                               "Customer's employees, agents, and/or subcontractors": 'PEOPLE_16',
#                               'Developer': 'PEOPLE_15',
#                               'Employees': 'PEOPLE_9',
#                               'Governmental regulatory authorities': 'PEOPLE_12',
#                               'Licensor': 'PEOPLE_6',
#                               'Public (in the context of information that is not confidential)': 'PEOPLE_13',
#                               'Reseller': 'PEOPLE_3',
#                               'Sujit Singh': 'ORGS_1',
#                               'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_6'},
#  'Customer5_MLSA_07292022': {'AG Holding Ltd': 'ORGS_64',
#                              'Accountants': 'PEOPLE_12',
#                              'Affiliates (as part of the agreement)': 'PEOPLE_3',
#                              'Arkieva': 'PEOPLE_2',
#                              'Arkieva (Supply Chain Consultants Inc. DBA Arkieva)': 'PEOPLE_24',
#                              'Cascade Biochem Limited': 'ORGS_62',
#                              'Consultants': 'PEOPLE_11',
#                              'Johnson Matthey Formox AB': 'ORGS_43',
#                              'Johnson Matthey Fuel Cells Limited': 'ORGS_66',
#                              'Johnson Matthey Fuel Cells, Inc': 'ORGS_73',
#                              'Johnson Matthey General Partner (Scotland) Limited': 'ORGS_67',
#                              'Johnson Matthey Holdings Inc': 'ORGS_72',
#                              'Johnson Matthey Holdings Limited': 'ORGS_6',
#                              'Johnson Matthey Inc': 'ORGS_76',
#                              'Johnson Matthey Investments Limited': 'ORGS_71',
#                              'Johnson Matthey Medical Device Components LLC': 'ORGS_77',
#                              'Johnson Matthey Poland Spólka z ograniczoną odpowiedzialnocnością': 'ORGS_34',
#                              'Johnson Matthey Precious Metals Limited': 'ORGS_68',
#                              'Johnson Matthey Process Technologies (Beijing) Co., Limited': 'ORGS_18',
#                              'Johnson Matthey Process Technologies, Inc': 'ORGS_74',
#                              'Johnson Matthey Research South Africa (Proprietary) Limited': 'ORGS_42',
#                              'Johnson Matthey SAS': 'ORGS_33',
#                              'Johnson Matthey Salts (Proprietary) Limited': 'ORGS_41',
#                              'Johnson Matthey Services (Trinidad and Tobago) Limited': 'ORGS_49',
#                              'Johnson Matthey Singapore Private Limited': 'ORGS_39',
#                              'Johnson Matthey South Africa Holdings Limited': 'ORGS_70',
#                              'Johnson Matthey Stationary Emissions Control LLC': 'ORGS_75',
#                              'Johnson Matthey Tianjin Holdings Limited': 'ORGS_65',
#                              'Johnson Matthey UK Holdings Limited': 'ORGS_52',
#                              'LiFePO4+C Licensing AG': 'ORGS_48',
#                              'Macfarlan Smith Portugal, Lda': 'ORGS_36',
#                              'Matthew Johnson': 'PEOPLE_23',
#                              'Matthey Finance Limited': 'ORGS_61',
#                              'Matthey Holdings Limited': 'ORGS_53',
#                              'Meconic Limited (in liquidation 10/12/2019)': 'ORGS_54',
#                              'Parties (implied to be the Developer and Customer)': 'PEOPLE_16',
#                              'Qingdao Johnson Matthey Hero Catalyst Company Limited (Joint Venture)': 'ORGS_22',
#                              'Red Maple LLC (Joint Venture)': 'ORGS_78',
#                              'Shanghai Bi Ke Clean Energy Technology Co., Ltd': 'ORGS_23',
#                              'Stepac Ambalaj Malzemeleri Sanayi Ve Ticaret Anonim Sirketi (in liquidation)': 'ORGS_50',
#                              'Stephen Oxley': 'ORGS_0',
#                              'Sujit Singh': 'ORGS_1',
#                              'Supply Chain Consultants Inc. (Arkieva)': 'PEOPLE_21',
#                              'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_80',
#                              'The Argent Insurance Co. Limited': 'ORGS_8',
#                              'Third party (indirectly mentioned)': 'PEOPLE_6',
#                              'Tracerco China Process Diagnostics & Instrumentation (Shanghai) Co Ltd': 'ORGS_15',
#                              'Tracerco Limited': 'ORGS_51',
#                              'Tracerco Radioactive Diagnostic Services Canada Inc': 'ORGS_12',
#                              'Tracerco do Brasil': 'ORGS_10'},
#  'Customer6_MLSA_08152023': {'Arkieva': 'ORGS_13',
#                              'C&M Auto Parts': 'ORGS_9',
#                              'Customer': 'PEOPLE_7',
#                              'Customer Incorporated (Customer)': 'ORGS_14',
#                              'Developer': 'PEOPLE_8',
#                              'General Repair': 'ORGS_10',
#                              'Justin Forbes': 'ORGS_0',
#                              'Justin Forbes (Vice President, Supply Chain)': 'PEOPLE_14',
#                              'King-O-Matic Limited Industries': 'ORGS_6',
#                              'Parties (implied to be the Developer and Customer)': 'PEOPLE_6',
#                              'ProKing Automotive Products': 'ORGS_7',
#                              'Proform': 'ORGS_12',
#                              'Recon Certified': 'ORGS_11',
#                              'Reseller': 'PEOPLE_3',
#                              'Sujit K Singh': 'ORGS_1',
#                              'Sujit K Singh (COO)': 'PEOPLE_15',
#                              'Supply Chain Consultants Inc. (DBA Arkieva)': 'ORGS_3',
#                              'Transmart': 'ORGS_8',
#                              'Transtar Autobody Technologies Inc.': 'ORGS_5',
#                              'Transtar Industries LLC': 'ORGS_4'},
#  'Customer7_MLSA_03152022': {'Accountants': 'PEOPLE_7',
#                              'Consultants': 'PEOPLE_6',
#                              'Customer': 'PEOPLE_15',
#                              "Customer's affiliates": 'PEOPLE_13',
#                              "Customer's consultants": 'PEOPLE_14',
#                              "Customer's employees": 'PEOPLE_12',
#                              'Developer': 'PEOPLE_16',
#                              'Employees': 'PEOPLE_5',
#                              'Governmental regulatory authorities': 'PEOPLE_8',
#                              'Licensor': 'PEOPLE_2',
#                              'Public (implied as a group)': 'PEOPLE_9',
#                              'Ryan Schaap': 'PEOPLE_23',
#                              'Ryan Schaap (CIO, VP-IT)': 'PEOPLE_25',
#                              'Ryan Schaap (CIO, VP-IT, 3/15/2022)': 'ORGS_0',
#                              'Sujit K Singh': 'PEOPLE_24',
#                              'Sujit K Singh (COO)': 'PEOPLE_26',
#                              'Sujit K Singh (COO, 3/15/2022)': 'ORGS_1',
#                              'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_9',
#                              'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_11',
#                              'Wells Enterprises, Inc.': 'ORGS_10',
#                              'Wells Enterprises, Inc. (Customer)': 'PEOPLE_27'},
#  'Customer87_MLSA_08082024': {'Affiliates (entities where customer has more than 50% ownership)': 'PEOPLE_3',
#                               'Arkieva': 'PEOPLE_2',
#                               'Arkieva (doing business as Arkieva)': 'ORGS_7',
#                               'Customer': 'PEOPLE_9',
#                               'Customer Incorporated (Customer)': 'ORGS_9',
#                               "Customer's": 'PEOPLE_12',
#                               'Developer': 'PEOPLE_10',
#                               "Developer's": 'PEOPLE_11',
#                               "Developer's agents": 'PEOPLE_14',
#                               "Developer's employees": 'PEOPLE_13',
#                               "Developer's subcontractors": 'PEOPLE_15',
#                               'Erin Armstrong': 'ORGS_1',
#                               'Parties (implied to be the Developer and Customer)': 'PEOPLE_8',
#                               'Reseller (an approved third party)': 'PEOPLE_4',
#                               'Sujit K Singh': 'ORGS_2',
#                               'Supply Chain Consultants Inc. (Developer)': 'ORGS_6',
#                               'Supply Chain Consultants Inc. (Developer) doing business as Arkieva (Arkieva)': 'ORGS_10',
#                               'U.S. Commerce Department': 'ORGS_0'},
#  'Customer8_MLSA_07152023': {'Abu Dhabi, United Arab Emirates': 'LOC_31',
#                              'Donaldson Korea Co., Ltd.': 'ORGS_38',
#                              'Donaldson Middle East Filtration System LLC': 'ORGS_39',
#                              'Donaldson Nederland B.V.': 'ORGS_40',
#                              'Donaldson Peru s.a.c.': 'ORGS_41',
#                              'Donaldson Polska Sp. z.o.o.': 'ORGS_42',
#                              'Donaldson S.A. de C.V.': 'ORGS_43',
#                              'Donaldson S.A.S.': 'ORGS_44',
#                              'Donaldson Schweiz GmbH': 'ORGS_45',
#                              'Donaldson Taiwan Inc.': 'ORGS_46',
#                              'Donaldson do Brasil Equipamentos Industriais Ltda': 'ORGS_16',
#                              'Filtros Partmo S.A.S.': 'ORGS_48',
#                              'Haan, Germany': 'LOC_14',
#                              'Hong Kong, S.A.R.': 'LOC_11',
#                              'Hull, United Kingdom': 'LOC_41',
#                              'Hørsholm, Denmark': 'LOC_37',
#                              'Isolere Bio, Inc.': 'ORGS_49',
#                              'Istanbul, Turkey': 'LOC_24',
#                              'Jakarta, Indonesia': 'LOC_45',
#                              'Kadan, Czech Republic': 'LOC_28',
#                              'Klasterec nad Ohri, Czech Republic': 'LOC_8',
#                              'Le Bozec Filtration Systems, S.A.S.': 'ORGS_50',
#                              'Leicester, United Kingdom': 'LOC_15',
#                              'Leuven, Belgium': 'LOC_2',
#                              'Lima, Peru': 'LOC_33',
#                              'Modderfontein, South Africa': 'LOC_21',
#                              'Moss, Norway': 'LOC_18',
#                              'Most, Czech Republic': 'LOC_44',
#                              'New Delhi, India': 'LOC_27',
#                              'Nippon Donaldson Ltd.': 'ORGS_51',
#                              'Nonthaburi, Thailand': 'LOC_23',
#                              'Ostiglia, Italy': 'LOC_29',
#                              'P.T. Donaldson Filtration Indonesia': 'ORGS_53',
#                              'Paris, France': 'LOC_25',
#                              'Parties (implied to be the Developer and Customer)': 'PEOPLE_7',
#                              'Pearson Arnold Industrial Services': 'ORGS_52',
#                              'Poole, United Kingdom': 'LOC_0',
#                              'Purilogics, LLC': 'ORGS_54',
#                              'Rayong, Thailand': 'LOC_40',
#                              'Reseller': 'PEOPLE_3',
#                              'Santiago, Chile': 'LOC_4',
#                              'Selangor Darul Ehsan, Malaysia': 'LOC_17',
#                              'Seoul, South Korea': 'LOC_30',
#                              'Shanghai, China Mainland': 'LOC_5',
#                              'Shoo 788AA Ltd.': 'ORGS_55',
#                              'Sujit K Singh': 'ORGS_4',
#                              'Sujit K Singh (COO, Customer)': 'PEOPLE_21',
#                              'Supply Chain Consultants Inc. (DBA Arkieva)': 'ORGS_6',
#                              'Taipei, Taiwan': 'LOC_39',
#                              'Thomas R. Scalf': 'ORGS_3',
#                              'Thomas R. Scalf (President, Enterprise Operations, Developer)': 'PEOPLE_22',
#                              'Toronto, Ontario, Canada': 'LOC_3',
#                              'Ultrafilter S.A.S.': 'ORGS_56',
#                              'Vienna, Austria': 'LOC_19',
#                              'Warsaw, Poland': 'LOC_34',
#                              'Wuxi, China Mainland': 'LOC_42',
#                              'Wyong, Australia': 'LOC_1',
#                              'Zurich, Switzerland': 'LOC_38'},
#  'Hero Arkieva MLSA 2020_Solventure_VF.docx': {'Accountants': 'PEOPLE_11',
#                                                'Arkieva': 'ORGS_2',
#                                                'Client Incorporated (Client)': 'ORGS_12',
#                                                'Client Incorporated (Customer)': 'ORGS_20',
#                                                'Consultants': 'PEOPLE_10',
#                                                'Customer': 'ORGS_1',
#                                                "Customer's": 'PEOPLE_23',
#                                                "Customer's affiliates": 'PEOPLE_17',
#                                                "Customer's consultants": 'PEOPLE_18',
#                                                "Customer's employees": 'PEOPLE_16',
#                                                'Developer': 'ORGS_0',
#                                                "Developer's": 'PEOPLE_22',
#                                                "Developer's agents": 'PEOPLE_25',
#                                                "Developer's employees": 'PEOPLE_24',
#                                                "Developer's subcontractors": 'PEOPLE_26',
#                                                'Director Plan & Deliver': 'ORGS_19',
#                                                'Employees': 'PEOPLE_9',
#                                                'Governmental regulatory authorities': 'PEOPLE_12',
#                                                'HERO AG': 'ORGS_22',
#                                                'Hero AG': 'ORGS_15',
#                                                'Licensor': 'PEOPLE_6',
#                                                'Mark Kaelen': 'ORGS_17',
#                                                'Mark Kaelen (again, listed as Director Plan & Deliver)': 'PEOPLE_35',
#                                                'PHI Project Lead': 'ORGS_18',
#                                                'Parties (implied to be the Developer and Customer)': 'PEOPLE_21',
#                                                'Phani Jagadeesh (PHI)': 'PEOPLE_41',
#                                                "Phani Jagadeesh (PHI) (again, possibly a typo or a different individual with the same name)\n\nNote: There are some potential typos or repeated names in the text, which could indicate that the same individuals are mentioned more than once. However, without additional context, it's difficult to confirm if these are indeed different individuals or just repeated names.": 'PEOPLE_43',
#                                                'Public (in the context of information that is not deemed confidential)': 'PEOPLE_13',
#                                                'Reseller': 'PEOPLE_3',
#                                                'Solventure': 'ORGS_14',
#                                                'Sujit Singh': 'PEOPLE_36',
#                                                'Sujit Singh Witte Van Cappellen': 'PEOPLE_39',
#                                                'Sujit Singh Witte Van Cappellen (again, listed as COO Chief Supply Chain Offer PHI Project Lead)': 'PEOPLE_34',
#                                                'Sujit Singh Witte Van Cappellen (again, possibly a typo or a different individual with the same name)': 'PEOPLE_42',
#                                                'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_21',
#                                                'Witte Van Cappellen': 'ORGS_16'},
#  'Invivo Arkieva LICENSE AGREEMENT_MLSA_Moulins Soufflet_vF.docx': {"7 Quai de l'Apport Paris, 91100 Corbeil-Essones": 'LOC_0',
#                                                                     "7 quai de l'Apport Paris": 'LOC_1',
#                                                                     '91100 Corbeil Essonnes': 'LOC_2',
#                                                                     'AIT': 'ORGS_10',
#                                                                     'Agro Ingredients TECNOLOGY': 'ORGS_9',
#                                                                     'Arkieva': 'PEOPLE_0',
#                                                                     'Arkieva is not mentioned again in the provided text, so there are no other companies mentioned.': 'ORGS_3',
#                                                                     'BVP Neuhausser': 'ORGS_12',
#                                                                     'Bertrand GUILLOTEAU': 'PEOPLE_27',
#                                                                     'Bertrand GUILLOTEAU (Customer)': 'ORGS_5',
#                                                                     'Bertrand Guilloteau': 'PEOPLE_21',
#                                                                     'Caen, 14460 Colombelles': 'LOC_4',
#                                                                     'Caen, 350 155 024': 'LOC_6',
#                                                                     'Client Incorporated (Client)': 'ORGS_13',
#                                                                     'Customer': 'PEOPLE_17',
#                                                                     'Customer Incorporated (Customer)': 'ORGS_20',
#                                                                     "Customer's affiliates": 'PEOPLE_14',
#                                                                     "Customer's consultants": 'PEOPLE_15',
#                                                                     "Customer's employees": 'PEOPLE_13',
#                                                                     'Developer': 'PEOPLE_16',
#                                                                     'Evry, 543 780 449': 'LOC_5',
#                                                                     'Licensor': 'PEOPLE_10',
#                                                                     'Licensors': 'PEOPLE_7',
#                                                                     'Meunerie': 'ORGS_7',
#                                                                     'Representative (of Developer)': 'PEOPLE_18',
#                                                                     'Representatives': 'PEOPLE_8',
#                                                                     'Reseller': 'PEOPLE_4',
#                                                                     'Reseller (implied, as part of the Service Agreement with Reseller)': 'ORGS_19',
#                                                                     'Société Anonyme au capital 14.640.000 Euros': 'ORGS_8',
#                                                                     'Solventure NV': 'ORGS_1',
#                                                                     'Solventure NV (Reseller)': 'PEOPLE_1',
#                                                                     'Soufflet Biotechnologies': 'ORGS_11',
#                                                                     'Sujit Singh': 'PEOPLE_28',
#                                                                     'Sujit Singh (Developer)': 'ORGS_6',
#                                                                     'Supply Chain Consultants Inc. DBA Arkieva (Arkieva)': 'ORGS_21',
#                                                                     'U.S. Commerce Department': 'ORGS_4',
#                                                                     "Zone d'Activités Commerciales Normandial 11 avenue du Pays de Caen 14460 Colombelles": 'LOC_3'},
#  'MBD SCC - Master License Agreement Agreed': {'Arkieva, Inc.': 'ORGS_1',
#                                                'Arkieva, Inc. (Developer)': 'PEOPLE_1',
#                                                'Customer': 'PEOPLE_7',
#                                                "Customer's consultants": 'PEOPLE_11',
#                                                "Customer's employees": 'PEOPLE_10',
#                                                "Customer's employees, consultants, or affiliates": 'PEOPLE_12',
#                                                'Developer': 'PEOPLE_8',
#                                                'Distributor': 'PEOPLE_9',
#                                                'Emmanuel PICHARD': 'PEOPLE_14',
#                                                'Licensor': 'PEOPLE_6',
#                                                'MESSIER-BUGATTI-DOWTY': 'ORGS_0',
#                                                'Messier-Bugatti-Dowty, Wheels and Brakes division': 'ORGS_4',
#                                                'Messier-Bugatty-Dowty (Customer)': 'PEOPLE_0',
#                                                'Safran Purchasing': 'ORGS_2',
#                                                'Sujit Singh': 'PEOPLE_13',
#                                                'Supply Chain Consultants, Inc. (SCC)': 'ORGS_3',
#                                                'Zemeter S&OP': 'ORGS_5'},
#  'Quorn_Arkieva MLSA.docx': {'Arkieva': 'PEOPLE_0',
#                              'Customer': 'PEOPLE_3',
#                              'David Artindale': 'PEOPLE_9',
#                              'David Artindale (Head of Procurement)': 'PEOPLE_11',
#                              'Developer': 'PEOPLE_2',
#                              'Marlow Foods Limited': 'ORGS_11',
#                              'Monde Nissin (UK) Limited.': 'ORGS_9',
#                              'Quorn Foods Inc.': 'ORGS_7',
#                              'Quorn Foods Sweden AB.': 'ORGS_10',
#                              'Quorn Smart Life GmbH.': 'ORGS_8',
#                              'Reseller': 'PEOPLE_4',
#                              'Reseller (implied, not explicitly named)': 'ORGS_6',
#                              'Solventure NV': 'ORGS_1',
#                              'Solventure NV (Reseller)': 'PEOPLE_1',
#                              'Stokesley': 'LOC_0',
#                              'Sujit Singh': 'PEOPLE_10',
#                              'Sujit Singh (COO)': 'PEOPLE_12',
#                              'Supply Chain Consultants Inc. DBA Arkieva': 'ORGS_12'}}

# %%
import copy
import re


def mask_text(text, entities):
    masked_text = copy.copy(text)
    for ent, placeholder in entities.items():
        if ent in ["Customer", "Developer", "Distributor"]:
            continue
        print(f"{ent} --> {placeholder}")
        masked_text = re.sub(ent, f"[{placeholder}]" , masked_text, count=0, flags=0)

    return masked_text
    
    
doc = md_docs[0]
doc_name = doc.stem
doc_text = doc.open().read()
print(mask_text(doc_text, placeholders[doc_name]))
# Out:
# Buckman Laboratories International Inc. --> ORGS_6
# Supply Chain Consultants, Inc. d/b/a Arkieva --> ORGS_1
# Licensors --> ORGS_2
# Representatives --> ORGS_3
# Distributors --> ORGS_4
# Arkieva --> ORGS_5
# Buckman Laboratories International Inc. (Customer) --> PEOPLE_0
# Supply Chain Consultants, Inc. d/b/a Arkieva (Developer) --> PEOPLE_1
# Licensor --> PEOPLE_6
# Customer's employees --> PEOPLE_10
# Customer's consultants --> PEOPLE_11
# Customer's employees, consultants, or affiliates --> PEOPLE_12
# Parties --> PEOPLE_16
# Parties (mentioned twice, but referring to the same entities as Developer and Distributor) --> PEOPLE_17
# Sujit K. Singh --> PEOPLE_18
# #### **MASTER LICENSE AGREEMENT**
#
# **Between Customer and [ORGS_1] Linden Green Center 5460 Fairmont Drive Wilmington, DE 19808 Telephone: 302-738-9215 Fed ID/TIN: 51-035 0007**
#
# Customer Name: BUCKMAN LABORATORIES INTERNATIONAL, INC.
#
# Address: 1256 North McLean Boulevard, Memphis Tennessee 38108-1241, U.S.A. Telephone: (901) 278-0330
#
# ATTN:
#
# | 1.0  | DEFINITIONS<br>3             |
# |------|------------------------------|
# | 2.0  | LICENSE3                     |
# | 3.0  | USE3                         |
# | 4.0  | PAYMENT<br>4                 |
# | 5.0  | SOFTWARE MAINTENANCE4        |
# | 6.0  | WARRANTIES AND REMEDIES<br>4 |
# | 7.0  | INDEMNITY5                   |
# | 8.0  | LIMITATION OF LIABILITY5     |
# | 9.0  | OWNERSHIP6                   |
# | 10.0 | TERMINATION OF DISTRIBUTOR6  |
# | 11.0 | CONFIDENTIALITY<br>6         |
# | 12.0 | TERMINATION7                 |
# | 13.0 | QUALITY CONTROL7             |
# | 14.0 | ASSIGNMENT7                  |
# | 15.0 | U.S. EXPORT RESTRICTIONS7    |
# | 16.0 | MISCELLANEOUS<br>8           |
#
# # <span id="page-2-0"></span>**1.0 DEFINITIONS**
#
# - A. "Products" means (i) the machine-readable object code version of the computer programs described in and specifically identified in one or more separately executed Product Schedule(s), appended hereto as Product Schedule A-1, A-2, etc. that Developer or its Distributor makes available, for use on the computer platform specified in the Product Schedule(s) (the "Software"), (ii) the published user manuals and documentation that Developer or its Distributor makes available for the Software (the "Documentation"), and (iii) the fixes, updates, upgrades, derivatives or new versions of the Software or Documentation that Developer or its Distributor may provide to Customer under this Agreement (the "Enhancements").
# - B. "Designated Hardware" means the hardware equipment specified in the applicable Product Schedule.
# - C. "[PEOPLE_16]" are [ORGS_6] ("Customer") and [ORGS_1] ("Developer").
# - D. "Distributor" is the agent that installs and supports the application at the Customer site.
#
# ## <span id="page-2-1"></span>**2.0 LICENSE**
#
# Developer hereby grants Customer, and Customer hereby accepts from Developer, a nonexclusive and nontransferable right and license to use the Products specified on one or more separately executed product schedules (the "Product Schedules") on "Designated Hardware" as defined in the applicable Product Schedule and subject to the terms and conditions specified in this Agreement.
#
# ## <span id="page-2-2"></span>**3.0 USE**
#
# - A. Customer may use the Products only in and for Customer's own internal purposes and business operations for the term specified in the applicable Product Schedule. Customer may use the Products only on the Designated Hardware while it possesses and operates the Designated Hardware. However, if the Designated Hardware becomes temporarily inoperable Customer may load and use the Software and Enhancements on another of its computer hardware systems until the Designated Hardware becomes operable. A separate installation for the sole purpose of establishing an acceptance or testing environment is permitted. Any other change in Designated Hardware (including any increase in the number of licensed servers or authorized concurrent users) will require Developer's or the Distributor's prior approval, which may be subject to additional reasonable charges.
# - B. Customer will not (a) permit any other person to use the Products directly or indirectly, whether on a time sharing, remote job entry or service bureau arrangement or (b) install
#
# the Software or Enhancements on a network or other multi-user computer system unless otherwise specified in the applicable Product Schedule A-1 on page 9 of this Agreement.
#
# - C. Customer may make a reasonable number of back-up or archival copies of the Software and Enhancements. Customer will reproduce all confidentiality and proprietary notices on each of these copies and maintain an accurate record of the location of each of these copies.
# - D. Customer will not otherwise copy, translate, modify, adapt, decompile, disassemble or reverse engineer the object code version of the Products, except as and to the extent expressly authorized by applicable law.
#
# ## <span id="page-3-0"></span>**4.0 PAYMENT**
#
# Payment for software will be governed by a separate agreement between the Customer and the Distributor. Customer's non-payment within ninety (90) days of its due date shall, at the option of the Developer, constitute a material breach of this Agreement.
#
# # <span id="page-3-1"></span>**5.0 SOFTWARE MAINTENANCE**
#
# - A. Software maintenance and support will be primarily provided by the Developer but it may designate its Distributor to provide such maintenance and support which will require and will be governed by a separate agreement between the Customer and the Distributor.
# - B. Developer will provide to the Distributor for release to the Customer (i) all the fixes and updates that Developer may make generally available as part of its standard Maintenance services, (ii) a replacement copy of the Product if the media becomes damaged or is destroyed to the extent that the Product is unusable.
#
# # <span id="page-3-2"></span>**6.0 WARRANTIES AND REMEDIES**
#
# - A. Limited Warranty. Developer warrants that it has the right to (i) enter into this Agreement and (ii) grant the license(s) hereunder. Developer also warrants that the Software will perform substantially as described in the related and accompanying Documentation.
#
# Customer acknowledges that the Products and all related technical information, documents and materials, are subject to export controls under the U.S. Export Administration Regulations. Customer will (a) comply strictly with all legal requirements established under these controls, (b) cooperate fully with Developer in any official or unofficial audit or inspection that relates to these controls, and (c) not export, re-export, divert or transfer, directly or indirectly, any such item or direct products thereof to any country that is embargoed by Executive Order or identified as embargoed in the Product Schedule, unless Customer has obtained prior written authorization from Developer and the U.S. Commerce Department. Upon notice to Customer, Developer may modify the list of countries identified as embargoed in the Product Schedule to conform to changes in the U.S. Export Administration Regulations.
#
# # <span id="page-7-0"></span>**16.0 MISCELLANEOUS**
#
# - A. All notices or approvals required or permitted under this Agreement must be given in writing to the address provided above as well as the Distributor, or to such other address as Developer or Customer shall provide to receive notices under this Agreement. Any terms and conditions of any unilateral letter, memorandum, purchase order or other writing issued by Customer shall not be binding on Developer. Any waiver or modification of this Agreement will not be effective unless executed in writing and signed by an authorized representative of Developer and Customer. This Agreement will bind Customer's successors-in-interest.
# - B. This Agreement will be governed by and interpreted in accordance with the laws of the State of Delaware, exclusive of choice of law provisions.
# - C. If any provision of this Agreement is held to be unenforceable, in whole or in part, such holding will not affect the validity of the other provisions of this Agreement, unless Developer in good faith determines the unenforceable provision to be essential, in which case Developer may terminate this Agreement effective immediately upon notice to Customer.
# - D. Neither party to this Agreement shall have authority to take any action that shall be binding on the other party, except as may be expressly provided herein or authorized in writing.
# - E. This Agreement constitutes the complete and entire statement of all conditions and representations of the agreement between Developer and Customer with respect to its subject matter and supersedes all prior writings or understandings.
#
# # THIS AGREEMENT IS NOT EFFECTIVE UNTIL SIGNED ON BEHALF OF BOTH PARTIES.
#
# ## **Read and Agreed:**
#
# By: By:
#
# Name: Name: [PEOPLE_18] Title: Title: COO, [ORGS_5] Date: Date: August 17, 2012
#
# # **PRODUCT SCHEDULE A-1**
#
# This product schedule becomes, upon execution by both parties, a part of the Master License Agreement (MLA) between [ORGS_1] ([ORGS_5]), and [ORGS_6] (Buckman) executed on *August 17 , 2012.*
#
# #### **Business Unit:** *Buckman*
#
# Zemeter Products Licensed:
#
# *Zemeter S&OP (Business Analyst, Demand Planner, S&OP Workbenches)*
#
# License Type:
#
#  *Yearly License subscription: To limit the short term out of pocket investment cost Zemeter is offered in a license subscription contract. In the "License subscription", the Zemeter customers pay license usage per month and subscribe per year to obtain the license usage rights for the next year. It eliminates the need for a software investment up front, but it does not lead to a permanent license usage right.*
#
# Designated Hardware:
#
# - *All required hardware and software to support the Zemeter applications will be provided by the Customer.*
# - *The Zemeter products listed will be located on Customer hardware at one or more Customer locations. Customer may also engage a 3rd party to host the software at their site on Customer's behalf.*
#
# Allowed Third [PEOPLE_16]:
#
# - *Hardware Hosting companies under contract with Buckman to host the hardware offsite or in the cloud.*
# - *Contracted Buckman employees to the extent that they have collaborative input into the planning process.*
#
# #### **Read and Agreed:**
#
# By: By:
#
# Name: Name: [PEOPLE_18] Title: Title: COO, [ORGS_5] Date: Date: August 17, 2012
